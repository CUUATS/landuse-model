# %%
# %load_ext autoreload
# %autoreload 2
import models, utils
import orca

# %%
orca.run([
    "rsh_simulate",              # residential sales hedonic
    "nrh_simulate",              # non-residential rent hedonic

    "households_relocation",     # households relocation model
    "hlcm_simulate",            # households location choice
    "households_transition",     # households transition

    "jobs_relocation",           # jobs relocation model
    "elcm_simulate",             # employment location choice
    "jobs_transition",           # jobs transition

    "feasibility",               # compute development feasibility
    "residential_developer",     # build residential buildings
    "non_residential_developer", # build non-residential buildings
])
# Out:
# Running iteration 1 with iteration value 2015
# Running step 'households_transition'
# 78058 agents before transition
# 81961 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 1 with iteration value 2015: 0.06 s
# Running iteration 2 with iteration value 2016
# Running step 'households_transition'
# 81961 agents before transition
# 86059 agents after transition
# Time to execute step 'households_transition': 0.03 s
# Total time to execute iteration 2 with iteration value 2016: 0.03 s
# Running iteration 3 with iteration value 2017
# Running step 'households_transition'
# 86059 agents before transition
# 90362 agents after transition
# Time to execute step 'households_transition': 0.04 s
# Total time to execute iteration 3 with iteration value 2017: 0.04 s
# Running iteration 4 with iteration value 2018
# Running step 'households_transition'
# 90362 agents before transition
# 94880 agents after transition
# Time to execute step 'households_transition': 0.04 s
# Total time to execute iteration 4 with iteration value 2018: 0.04 s
# Running iteration 5 with iteration value 2019
# Running step 'households_transition'
# 94880 agents before transition
# 99624 agents after transition
# Time to execute step 'households_transition': 0.04 s
# Total time to execute iteration 5 with iteration value 2019: 0.04 s
# Running iteration 6 with iteration value 2020
# Running step 'households_transition'
# 99624 agents before transition
# 104605 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 6 with iteration value 2020: 0.05 s
# Running iteration 7 with iteration value 2021
# Running step 'households_transition'
# 104605 agents before transition
# 109835 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 7 with iteration value 2021: 0.05 s
# Running iteration 8 with iteration value 2022
# Running step 'households_transition'
# 109835 agents before transition
# 115327 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 8 with iteration value 2022: 0.05 s
# Running iteration 9 with iteration value 2023
# Running step 'households_transition'
# 115327 agents before transition
# 121093 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 9 with iteration value 2023: 0.05 s
# Running iteration 10 with iteration value 2024
# Running step 'households_transition'
# 121093 agents before transition
# 127148 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 10 with iteration value 2024: 0.05 s
# Running iteration 11 with iteration value 2025
# Running step 'households_transition'
# 127148 agents before transition
# 133505 agents after transition
# Time to execute step 'households_transition': 0.10 s
# Total time to execute iteration 11 with iteration value 2025: 0.10 s
# Running iteration 12 with iteration value 2026
# Running step 'households_transition'
# 133505 agents before transition
# 140180 agents after transition
# Time to execute step 'households_transition': 0.05 s
# Total time to execute iteration 12 with iteration value 2026: 0.05 s
# Running iteration 13 with iteration value 2027
# Running step 'households_transition'
# 140180 agents before transition
# 147189 agents after transition
# Time to execute step 'households_transition': 0.06 s
# Total time to execute iteration 13 with iteration value 2027: 0.06 s
# Running iteration 14 with iteration value 2028
# Running step 'households_transition'
# 147189 agents before transition
# 154548 agents after transition
# Time to execute step 'households_transition': 0.06 s
# Total time to execute iteration 14 with iteration value 2028: 0.06 s
# Running iteration 15 with iteration value 2029
# Running step 'households_transition'
# 154548 agents before transition
# 162275 agents after transition
# Time to execute step 'households_transition': 0.06 s
# Total time to execute iteration 15 with iteration value 2029: 0.06 s
# Running iteration 16 with iteration value 2030
# Running step 'households_transition'
# 162275 agents before transition
# 170389 agents after transition
# Time to execute step 'households_transition': 0.06 s
# Total time to execute iteration 16 with iteration value 2030: 0.06 s
# Running iteration 17 with iteration value 2031
# Running step 'households_transition'
# 170389 agents before transition
# 178908 agents after transition
# Time to execute step 'households_transition': 0.07 s
# Total time to execute iteration 17 with iteration value 2031: 0.07 s
# Running iteration 18 with iteration value 2032
# Running step 'households_transition'
# 178908 agents before transition
# 187853 agents after transition
# Time to execute step 'households_transition': 0.07 s
# Total time to execute iteration 18 with iteration value 2032: 0.07 s
# Running iteration 19 with iteration value 2033
# Running step 'households_transition'
# 187853 agents before transition
# 197246 agents after transition
# Time to execute step 'households_transition': 0.07 s
# Total time to execute iteration 19 with iteration value 2033: 0.07 s
# Running iteration 20 with iteration value 2034
# Running step 'households_transition'
# 197246 agents before transition
# 207108 agents after transition
# Time to execute step 'households_transition': 0.08 s
# Total time to execute iteration 20 with iteration value 2034: 0.08 s
# Running iteration 21 with iteration value 2035
# Running step 'households_transition'
# 207108 agents before transition
# 217463 agents after transition
# Time to execute step 'households_transition': 0.08 s
# Total time to execute iteration 21 with iteration value 2035: 0.08 s
# Running iteration 22 with iteration value 2036
# Running step 'households_transition'
# 217463 agents before transition
# 228336 agents after transition
# Time to execute step 'households_transition': 0.16 s
# Total time to execute iteration 22 with iteration value 2036: 0.16 s
# Running iteration 23 with iteration value 2037
# Running step 'households_transition'
# 228336 agents before transition
# 239753 agents after transition
# Time to execute step 'households_transition': 0.09 s
# Total time to execute iteration 23 with iteration value 2037: 0.09 s
# Running iteration 24 with iteration value 2038
# Running step 'households_transition'
# 239753 agents before transition
# 251741 agents after transition
# Time to execute step 'households_transition': 0.10 s
# Total time to execute iteration 24 with iteration value 2038: 0.10 s
# Running iteration 25 with iteration value 2039
# Running step 'households_transition'
# 251741 agents before transition
# 264328 agents after transition
# Time to execute step 'households_transition': 0.11 s
# Total time to execute iteration 25 with iteration value 2039: 0.11 s
