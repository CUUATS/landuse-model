# %%
import models, utils
import orca

# %%
orca.run(["households_relocation"])
# Out:
# Running step 'households_relocation'
# Total agents: 78058
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-5a7eeb6dd0f9> in <module>()
# ----> 1 orca.run(["households_relocation"])
#
# c:\users\hlc42705\desktop\bayarea_urbansim\src\orca\orca\orca.pyc in run(steps, iter_vars, data_out, out_interval)
#    1874                 step = get_step(step_name)
#    1875                 t2 = time.time()
# -> 1876                 step()
#    1877                 print("Time to execute step '{}': {:.2f} s".format(
#    1878                       step_name, time.time() - t2))
#
# c:\users\hlc42705\desktop\bayarea_urbansim\src\orca\orca\orca.pyc in __call__(self)
#     778             kwargs = _collect_variables(names=self._argspec.args,
#     779                                         expressions=self._argspec.defaults)
# --> 780             return self._func(**kwargs)
# ...
